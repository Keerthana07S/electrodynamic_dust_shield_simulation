# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.interpolate import UnivariateSpline

# %%
df = pd.read_csv('eds_average.csv')
df
# Out:
#      Time(s)      Force(N)   Acceleration In The X-direction (m/s^2)  \
# 0       0.00  2.336530e-09                              2.018525e-05
# 1       0.01  4.910835e-09                              1.555300e-05
# 2       0.02 -7.082251e-10                              9.249974e-06
# 3       0.03 -4.820341e-09                              2.914347e-06
# 4       0.04 -1.142142e-08                             -1.957112e-06
# ..       ...           ...                                       ...
# 96      0.96 -1.139151e-08                             -2.860730e-07
# 97      0.97 -4.749185e-09                             -3.173996e-07
# 98      0.98 -6.284661e-10                             -2.038829e-07
# 99      0.99  4.962602e-09                              8.431883e-12
# 100     1.00  2.336560e-09                              1.998623e-07
#
#       Acceleration In The Y-direction (m/s^2)  \
# 0                                1.813623e-05
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(df['Time(s)'], df[' Acceleration In The X-direction (m/s^2)'])
ax.set_xlabel('Time (s)')
ax.set_ylabel('Acceleration In The X-direction (m/s^2)')
ax.set_title('Acceleration-Time Graph In The X-direction')
ax.grid(True)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(df['Time(s)'], df[' Acceleration In The Y-direction (m/s^2)'])
ax.set_xlabel('Time (s)')
ax.set_ylabel('Acceleration In The Y-direction (m/s^2)')
ax.set_title('Acceleration-Time Graph In The Y-direction')
ax.grid(True)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(df[' Acceleration In The X-direction (m/s^2)'], df[' Acceleration In The Y-direction (m/s^2)'])
ax.set_xlabel('Acceleration In The X-direction(m/s^2)')
ax.set_ylabel('Acceleration In The Y-direction (m/s^2)')
ax.set_title('Acceleration Graph XY directions')
ax.grid(True)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(df['Time(s)'], df[' Velocity In The X-direction (m/s)'])
ax.set_xlabel('Time (s)')
ax.set_ylabel('Velocity In The X-direction (m/s)')
ax.set_title('Velocity-Time Graph In The X-direction')
ax.grid(True)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(df['Time(s)'], df[' Velocity In The Y-direction (m/s)'])
ax.set_xlabel('Time (s)')
ax.set_ylabel('Velocity In The Y-direction (m/s)')
ax.set_title('Velocity-Time Graph In The Y-direction')
ax.grid(True)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 12))
ax.plot(df[' Velocity In The X-direction (m/s)'], df[' Velocity In The Y-direction (m/s)'])
ax.set_xlabel('Velocity In The X-direction(m/s)')
ax.set_ylabel('Velocity In The Y-direction (m/s)')
ax.set_title('Velocity Graph XY directions')
ax.grid(True)

plt.show()

# %%
from scipy.integrate import cumtrapz

# %%
x = df[ "Time(s)"]
y = df[ " Velocity In The X-direction (m/s)"]

# %%
position = cumtrapz(y, x, initial=0)

# %%
plt.plot(x, position)
plt.xlabel("Time(s)")
plt.ylabel("Position In The X Direction(m)")
plt.show()

# %%
x1 = df[ "Time(s)"]
y1 = df[ " Velocity In The Y-direction (m/s)"]

position1 = cumtrapz(y1, x1, initial=0)

# %%
plt.plot(x1, position1)
plt.xlabel("Time(s)")
plt.ylabel("Position In The Y Direction(m)")
plt.show()

# %%
plt.plot(position, position1)
plt.xlabel("Position In The X Direction(m)")
plt.ylabel("Position In The Y Direction(m)")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(20, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df[ "Time(s)"], position, position1)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Position In The X-direction (m)')
ax.set_zlabel('Position In The Y-direction (m)')

ax.yaxis.set_major_formatter(mticker.ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 10
#       7 ax.set_ylabel('Position In The X-direction (m)')
#       8 ax.set_zlabel('Position In The Y-direction (m)')
# ---> 10 ax.yaxis.set_major_formatter(mticker.ScalarFormatter(useMathText=True))
#      11 ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
#      13 plt.show()
#
# NameError: name 'mticker' is not defined
